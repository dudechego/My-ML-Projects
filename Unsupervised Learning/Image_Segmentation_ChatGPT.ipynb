# %% [markdown]
# <a href="https://colab.research.google.com/github/dudechego/My-ML-Projects/blob/main/Unsupervised%20Learning/Image_Segmentation_ChatGPT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
from google.colab import drive

from sklearn.cluster import KMeans

# %%
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
madrid = "/content/drive/MyDrive/datasets/madrid.jpeg"
liverpool = "/content/drive/MyDrive/datasets/liverpool.jpeg"

image = mpl.image.imread(madrid)
plt.imshow(image)

# %%
image2 = mpl.image.imread(liverpool)
plt.imshow(image2)

# %%
print(image.shape)
print(image2.shape)
# Out:
# (251, 201, 3)
# (225, 225, 3)

# %%
#Reshape our image
X = image.reshape(-1, 3)
X2 = image2.reshape(-1, 3)

print(X.shape)
print(X2.shape)
# Out:
# (50451, 3)
# (50625, 3)

# %%
#Use our KMeans Model
kmeans = KMeans(n_clusters=20, n_init=5)
kmeans
# Out:
# KMeans(n_clusters=20, n_init=5)

# %%
model1 = kmeans
model1.fit(X)
model2 = kmeans
model2.fit(X2)
# Out:
# KMeans(n_clusters=2, n_init=5)

# %%
kmeans.fit(X)
# Out:
# KMeans(n_clusters=20, n_init=5)

# %%
segmented_img = kmeans.cluster_centers_[kmeans.labels_]

segmented_img = segmented_img.reshape(image.shape)
print("")

# %%
plt.imshow(segmented_img/ 255)

# %%
kmeans.fit(X2)
# Out:
# KMeans(n_clusters=3, n_init=5)

# %%
segmented_img2 = kmeans.cluster_centers_[kmeans.labels_]

segmented_img2 = segmented_img2.reshape(image2.shape)
print("")

# %%
plt.imshow(segmented_img2 / 255)

# %%
import cv2

cv2.imwrite("madrid1.jpeg", cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
cv2.imwrite("madrid2.jpeg", cv2.cvtColor(segmented_img.astype("uint8"), cv2.COLOR_BGR2RGB))
# Out:
# True

# %%
madrid2 = mpl.image.imread("/content/madrid2.jpeg")
plt.imshow(madrid2)
madrid2.shape
# Out:
# (251, 201, 3)

# %%
madrid1 = mpl.image.imread("/content/madrid1.jpeg")
plt.imshow(madrid1)
madrid1.shape
# Out:
# (251, 201, 3)
