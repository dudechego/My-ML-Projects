# %% [markdown]
# <a href="https://colab.research.google.com/github/dudechego/My-ML-Projects/blob/main/Unsupervised%20Learning/Market_Basket_Analysis_ChatGPT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from google.colab import drive
from mlxtend.frequent_patterns import apriori, association_rules

import warnings
warnings.simplefilter("ignore", DeprecationWarning)

# %%
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
path = "/content/drive/MyDrive/datasets/movies recommendation.csv"
movies_data = pd.read_csv(path)
movies_data.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
new_data = movies_data.iloc[:10000, :]
new_data
# Out:
#       movieId                                              title  \
# 0           1                                   Toy Story (1995)
# 1           2                                     Jumanji (1995)
# 2           3                            Grumpier Old Men (1995)
# 3           4                           Waiting to Exhale (1995)
# 4           5                 Father of the Bride Part II (1995)
# ...       ...                                                ...
# 9995    33750           Innocent Voices (Voces inocentes) (2004)
# 9996    33755  Godzilla vs. Biollante (Gojira vs. Biorante) (...
# 9997    33760                   Anna and the King of Siam (1946)
# 9998    33767                           Good Neighbor Sam (1964)
# 9999    33779                 Eddie Izzard: Dress to Kill (1999)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# ...

# %%
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   movieId  10000 non-null  int64
#  1   title    10000 non-null  object
#  2   genres   10000 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 234.5+ KB

# %%
#Data Preparation
new_data["title"] = new_data["title"].str.strip()
new_data.head()
# Out:
# /tmp/ipython-input-1147307891.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_data["title"] = new_data["title"].str.strip()
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
new_data.shape
# Out:
# (10000, 3)

# %%
new_data["genres"].value_counts()
# Out:
# genres
# Drama                                                      1703
# Comedy                                                      927
# Comedy|Drama                                                488
# Drama|Romance                                               437
# Comedy|Romance                                              357
#                                                            ...
# Adventure|Animation|Children|Comedy|Fantasy|Sci-Fi|IMAX       1
# Adventure|Drama|War|Western                                   1
# Animation|Comedy|Drama                                        1
# Action|Crime|Film-Noir|Mystery|Thriller                       1
# Action|Adventure|Documentary                                  1
# Name: count, Length: 780, dtype: int64

# %%
my_data = (new_data.groupby(["title"])["genres"].
sum().unstack().reset_index())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2292634499.py in <cell line: 0>()
#       1 my_data = (new_data.groupby(["title"])["genres"].
# ----> 2 sum().unstack().reset_index())
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py in unstack(self, level, fill_value, sort)
#    4613         from pandas.core.reshape.reshape import unstack
#    4614
# -> 4615         return unstack(self, level, fill_value, sort)
#    4616
#    4617     # ----------------------------------------------------------------------
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/reshape/reshape.py in unstack(obj, level, fill_value, sort)
#     509         # Give nicer error messages when unstack a Series whose
#     510         # Index is not a MultiIndex.
# --> 511         raise ValueError(
# ...
